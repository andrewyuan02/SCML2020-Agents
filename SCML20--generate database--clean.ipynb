# %%
#This script can be used to generate the database which feeds into the uncertainty model.

#Author: Eddy

# %%
import pandas as pd
import numpy as np
import scml
import sys
from typing import List, Union
from scml.scml2020 import SCML2020Agent
from scml.scml2020.agents import DecentralizingAgent, BuyCheapSellExpensiveAgent, RandomAgent

# %%
#Add whatever folder the generatedata.py script is in on your computer
#This has to be run on the environment where SCML and NEGMAS packages were imported
sys.path.append(r'C:/FILL IN HERE.../SCML/scml2020/myagent')
import generatedata as gd

# %%
def produce_game_log(T,L,full_log_df):

    cols = set(full_log_df.columns)

    cols_to_keep = set()
    for i in range(L):
        cols_to_keep.add('sold_quantity_' + str(i))
        cols_to_keep.add('unit_price_' + str(i))

    drop_cols = cols - cols_to_keep

    #create a column for the timestep
    #should this start from 0 or 1?
    t = []
    for i in range(T):
        t.append(str(i))

    # Select only the data that we need for this computation
    y = full_log_df.drop(drop_cols, axis = 1)
    y.insert(0,'t',t)
    return y

# %%
def vertical_concat(list_of_logs):
    df = list_of_logs[0]
    game_index_column = [1] * len(df.index)
    
    for i in range(1,len(list_of_logs)):
        df = pd.concat([df, list_of_logs[i]], ignore_index=True)
        temp_game_index_column = [i+1] * len(list_of_logs[i].index)
        game_index_column.extend(temp_game_index_column)
        
    #print((game_index_column))    
    df.insert(0,'game_index', game_index_column)
    return df

# %%
def generate_model_input(n_steps: int, competitors: List[Union[str, SCML2020Agent]], n_agents_per_competitor):
    """Takes in inputs and generates three game logs' worth of relevant game info according to this input. This
    can be fed into the uncertainty prediction model.
    
    Args:
        n_steps: Integer containing how many time steps each game will have.
        competitors: A list of the agents to be included in the simulation. For instance, 
            COMPETITORS = [DecentralizingAgent, BuyCheapSellExpensiveAgent, RandomAgent].
        n_agents_per_competitor: Integer representing how many agents each competitor will have.
        
    Returns:
        Pandas dataframe which has the three game logs' worth of relevant game info.
        
    """
    #1. generate full worlds with all data
    worlds = gd.generate_world(n_steps,
                        COMPETITORS,
                        n_agents_per_competitor)
    worlds_df_list = [];
    for i, world in enumerate(worlds):
        world.run()
        worlds_df_list.append(world.stats_df)
    
    #2. produce game logs of relevant information from full world data
    df_logs_list = []
    for worlds_df in worlds_df_list:
        df_logs_list.append(produce_game_log(n_steps,10,worlds_df))
    
    #3. vertically concatenate all the game logs together
    return vertical_concat(df_logs_list)

# %%
#The competitor agents can be edited here. Then run generate_model_input.
COMPETITORS = [DecentralizingAgent, BuyCheapSellExpensiveAgent, RandomAgent]
generate_model_input(10, COMPETITORS, 1)
# Out:
#     game_index  t  sold_quantity_0  unit_price_0  sold_quantity_1  \
# 0            1  0               20          10.0                0
# 1            1  1               20          10.0                0
# 2            1  2               20          10.0               15
# 3            1  3               20          10.0               20
# 4            1  4               20          10.0               12
# 5            1  5                0           NaN               13
# 6            1  6                0           NaN                9
# 7            1  7                0           NaN                5
# 8            1  8                0           NaN                0
# 9            1  9                0           NaN                0
# 10           2  0               20          10.0                0
# 11           2  1               20          10.0                0
# 12           2  2               20          10.0                0
# 13           2  3               20          10.0                8
# 14           2  4               20          10.0                3
# 15           2  5                0           NaN                0
# 16           2  6                0           NaN                5
# 17           2  7                0           NaN                0
# 18           2  8                0           NaN                0
# 19           2  9                0           NaN                0
# 20           3  0               20          10.0                0
# 21           3  1               20          10.0                0
# 22           3  2               20          10.0                4
# 23           3  3               20          10.0               11
# 24           3  4               20          10.0                1
# 25           3  5                0           NaN                1
# 26           3  6                0           NaN               17
# 27           3  7                0           NaN                5
# 28           3  8                0           NaN                0
# 29           3  9                0           NaN                0
#
#     unit_price_1  sold_quantity_2  unit_price_2  sold_quantity_3  \
# 0            NaN                0           NaN                0
# 1            NaN                0           NaN                0
# 2       2.400000                0           NaN                6
# 3       2.550000               10     31.000000                6
# 4       2.166667                5     31.000000                6
# 5       1.615385               10     31.500000                4
# 6       1.666667               25     31.000000                8
# 7       7.000000                5     32.000000                8
# 8            NaN               10     32.000000                0
# 9            NaN                4     31.000000                0
# 10           NaN                0           NaN                0
# 11           NaN                0           NaN                0
# 12           NaN                0           NaN                9
# 13      1.250000                7     32.000000               15
# 14      2.000000                5     36.000000               10
# 15           NaN                5     36.000000               23
# 16      4.000000                3     27.000000                4
# 17           NaN                7     34.428571                0
# 18           NaN                0           NaN                0
# 19           NaN                2     27.000000                0
# 20           NaN                0           NaN                0
# 21           NaN                0           NaN                0
# 22      2.250000                5      2.000000                3
# 23      1.363636                6     11.833333                2
# 24      4.000000               15     15.666667                5
# 25      1.000000                4     46.000000                8
# 26      1.117647                0           NaN               12
# 27      2.000000                6     39.833333                6
# 28           NaN                5     46.800000                0
# 29           NaN                6     46.833333                0
#
#     unit_price_3  sold_quantity_4  unit_price_4  sold_quantity_5  unit_price_5
# 0            NaN                0           NaN                0           NaN
# 1            NaN                0           NaN                0           NaN
# 2      16.000000                0           NaN                0           NaN
# 3      16.000000                6     60.500000                0           NaN
# 4      16.000000                9     61.888889                0           NaN
# 5      16.000000                4     21.000000               20          51.0
# 6      16.000000                6     60.500000               20          51.0
# 7      16.000000               16     72.687500                8          51.0
# 8            NaN                4     79.250000               20          51.0
# 9            NaN               10     80.000000               20          51.0
# 10           NaN                0           NaN                0           NaN
# 11           NaN                0           NaN                0           NaN
# 12      6.333333                0           NaN                0           NaN
# 13      6.866667                0           NaN                0           NaN
# 14      6.200000               12     47.333333                0           NaN
# 15      9.869565                3     19.000000               20          43.0
# 16      1.000000                5     55.000000               20          43.0
# 17           NaN                0           NaN               20          43.0
# 18           NaN                0           NaN                4          43.0
# 19           NaN                0           NaN                1          43.0
# 20           NaN                0           NaN                0           NaN
# 21           NaN                0           NaN                0           NaN
# 22     22.000000                5     33.000000                0           NaN
# 23     22.000000                9     59.222222                0           NaN
# 24     34.000000                2     92.000000                0           NaN
# 25     47.000000                2     92.000000               20          81.0
# 26     47.833333                7     93.714286               20          81.0
# 27     55.333333                6     93.333333               20          81.0
# 28           NaN                1     92.000000               11          81.0
# 29           NaN               10     94.000000               15          81.0
